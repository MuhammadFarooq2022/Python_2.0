# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Optimus/Documents/payments.csv")
df.head()
# Out:
#    customerNumber checkNumber paymentDate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14
# 3             112    BO864823  2004-12-17  14191.12
# 4             112     HQ55022  2003-06-06  32641.98

# %%
plt.hist(df["amount"])
# Out:
# (array([51., 53., 66., 54., 32.,  5.,  4.,  3.,  2.,  3.]),
#  array([   615.45 ,  12570.563,  24525.676,  36480.789,  48435.902,
#          60391.015,  72346.128,  84301.241,  96256.354, 108211.467,
#         120166.58 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df["amount"])
# Out:
# <Axes: >

# %%
sns.boxenplot(df["amount"])
# Out:
# <Axes: >
